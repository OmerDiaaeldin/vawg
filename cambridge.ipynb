# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv("data/raw/Crime_Reports_20240701.csv")
raw_data.head()
# Out:
#   File Number          Date of Report                      Crime Date Time  \
# 0  2009-01323  02/21/2009 09:53:00 AM             02/21/2009 09:20 - 09:30
# 1  2009-01324  02/21/2009 09:59:00 AM  02/20/2009 22:30 - 02/21/2009 10:00
# 2  2009-01327  02/21/2009 12:32:00 PM  02/19/2009 21:00 - 02/21/2009 12:00
# 3  2009-01331  02/21/2009 03:05:00 PM             02/21/2009 15:00 - 15:10
# 4  2009-01346  02/22/2009 05:02:00 AM                     02/22/2009 05:02
#
#             Crime  Reporting Area     Neighborhood  \
# 0         Threats           105.0   East Cambridge
# 1      Auto Theft          1109.0  North Cambridge
# 2     Hit and Run          1109.0  North Cambridge
# 3  Larceny (Misc)          1303.0  Strawberry Hill
# 4             OUI           105.0   East Cambridge
#
#                             Location
# 0         100 OTIS ST, Cambridge, MA
# 1      400 RINDGE AVE, Cambridge, MA
# 2      400 RINDGE AVE, Cambridge, MA
# 3      0 NORUMBEGA ST, Cambridge, MA
# ...

# %%
# !ls scripts
# Out:
#  address_to_coor.py  'final address mappings.json'   merge_addresses.py
#  empty.csv	      mapping.json		     temp.py

# %% [markdown]
# <h3>pick only the relevant crimes</h3>

# %%
crimes = ['Harassment', 'Sex Offender Violation', 'Stalking', 'Domestic Dispute']

df = raw_data[raw_data.loc[:,'Crime'].map(lambda x: x in crimes)]

# %%
df.head()
# Out:
#     File Number          Date of Report                      Crime Date Time  \
# 70   2009-00327  01/13/2009 05:34:00 PM             01/10/2009 12:00 - 12:15
# 133  2009-05124  07/16/2009 10:49:00 AM  07/09/2009 12:00 - 07/16/2009 10:30
# 183  2009-02406  04/04/2009 02:47:00 PM                     04/04/2009 14:47
# 232  2009-01677  03/07/2009 01:17:00 PM             03/07/2009 13:10 - 13:15
# 476  2009-01507  02/28/2009 12:25:00 PM  02/26/2009 11:00 - 02/28/2009 11:00
#
#                       Crime  Reporting Area     Neighborhood  \
# 70               Harassment          1109.0  North Cambridge
# 133              Harassment           610.0    Mid-Cambridge
# 183  Sex Offender Violation           501.0    Cambridgeport
# 232              Harassment           701.0        Riverside
# 476              Harassment           604.0    Mid-Cambridge
#
#                                          Location
# 70                  400 RINDGE AVE, Cambridge, MA
# ...

# %% [markdown]
# <h2>add latitude and longitude information</h2>

# %%
import json
with open('scripts/final address mappings.json') as file:
    address_to_coor = json.load(file)

# %%
address_to_coor
# Out:
# {'400 RINDGE AVE, Cambridge, MA': [-71.13948064364068, 42.393763699999994],
#  '300 BROADWAY, Cambridge, MA': [-71.098645, 42.368288],
#  'Massachusetts Ave & SIDNEY ST, Cambridge, MA': [-71.0993294, 42.3626687],
#  '800 Massachusetts Ave, Cambridge, MA': [-71.105898, 42.366605],
#  '0 MAPLE AVE, Cambridge, MA': [-71.10457876349527, 42.37262368669389],
#  '1100 CAMBRIDGE ST, Cambridge, MA': [-71.0957408888889, 42.37298555555555],
#  '400 WASHINGTON ST, Cambridge, MA': [-71.1003589, 42.3657525],
#  '0 CENTRE ST, Cambridge, MA': [-71.10900496943059, 42.369594051090836],
#  '100 MAIN ST, Cambridge, MA': [-71.0825608, 42.3614311],
#  '100 INMAN ST, Cambridge, MA': [-71.10132865945451, 42.37161275],
#  '600 Massachusetts Ave, Cambridge, MA': [-71.10339916975049,
#   42.364701249999996],
#  '0 Ware St, Cambridge, MA': [-71.11293833655162, 42.37284436871419],
#  '200 PROSPECT ST, Cambridge, MA': [-71.10022730769231, 42.3702613076923],
# ...
